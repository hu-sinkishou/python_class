# %%
print("hello")
# Out:
# hello

# %%
base = 10
height = 7
area = base * height / 2
print(area)
# Out:
# 35.0

# %%
name = "人参 バナナ"
msg = "こんにちは！" + name + "さん。お元気ですか？"
print(msg)
# Out:
# こんにちは！人参 バナナさん。お元気ですか？
